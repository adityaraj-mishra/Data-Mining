# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df=pd.read_csv('single_family_home_values.csv')

# %%
df.head(2)
# Out:
#           id            address    city state  zipcode  latitude   longitude  \
# 0   39525749    8171 E 84th Ave  Denver    CO    80022  39.84916 -104.893468
# 1  184578398  10556 Wheeling St  Denver    CO    80022  39.88802 -104.830930
#
#    bedrooms  bathrooms  rooms  squareFootage  lotSize  yearBuilt lastSaleDate  \
# 0         3        2.0      6           1378     9968     2003.0   2009-12-17
# 1         2        2.0      6           1653     6970     2004.0   2004-09-23
#
#    lastSaleAmount priorSaleDate  priorSaleAmount  estimated_value
# 0           75000    2004-05-13         165700.0           239753
# 1          216935           NaN              NaN           343963

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (15000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15000 non-null  int64
#  1   address          15000 non-null  object
#  2   city             15000 non-null  object
#  3   state            15000 non-null  object
#  4   zipcode          15000 non-null  int64
#  5   latitude         14985 non-null  float64
#  6   longitude        14985 non-null  float64
#  7   bedrooms         15000 non-null  int64
#  8   bathrooms        15000 non-null  float64
#  9   rooms            15000 non-null  int64
#  10  squareFootage    15000 non-null  int64
#  11  lotSize          15000 non-null  int64
#  12  yearBuilt        14999 non-null  float64
#  13  lastSaleDate     15000 non-null  object
#  14  lastSaleAmount   15000 non-null  int64
#  15  priorSaleDate    11173 non-null  object
#  16  priorSaleAmount  11287 non-null  float64
#  17  estimated_value  15000 non-null  int64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#                  id       zipcode      latitude     longitude      bedrooms  \
# count  1.500000e+04  15000.000000  14985.000000  14985.000000  15000.000000
# mean   5.176229e+07  80204.919467     39.740538   -104.964076      2.708400
# std    6.190876e+07      9.715263      0.023555      0.039788      0.897231
# min    1.433670e+05  80022.000000     39.614531   -105.108440      0.000000
# 25%    1.004802e+07  80205.000000     39.727634   -104.978737      2.000000
# 50%    2.563241e+07  80206.000000     39.748048   -104.957689      3.000000
# 75%    5.114222e+07  80207.000000     39.758214   -104.937522      3.000000
# max    3.209481e+08  80209.000000     39.888020   -104.830930     15.000000
#
#           bathrooms         rooms  squareFootage       lotSize     yearBuilt  \
# count  15000.000000  15000.000000   15000.000000   15000.00000  14999.000000
# mean       2.195067      6.164133    1514.504400    5820.76620   1929.517168
# std        1.166279      1.958601     830.635999    3013.27947     29.937051
# min        0.000000      0.000000     350.000000     278.00000   1874.000000
# 25%        1.000000      5.000000     986.000000    4620.00000   1907.000000
# 50%        2.000000      6.000000    1267.500000    5950.00000   1925.000000
# 75%        3.000000      7.000000    1766.250000    6270.00000   1949.000000
# max       12.000000     39.000000   10907.000000  122839.00000   2016.000000
#
#        lastSaleAmount  priorSaleAmount  estimated_value
# count    1.500000e+04     1.128700e+04     1.500000e+04
# mean     4.053563e+05     2.594350e+05     6.371625e+05
# std      7.756998e+05     3.379387e+05     5.044185e+05
# min      2.590000e+02     0.000000e+00     1.477670e+05
# 25%      1.940000e+05     1.100000e+05     3.984348e+05
# 50%      3.200000e+05     2.100000e+05     5.183575e+05
# 75%      4.632000e+05     3.302400e+05     6.879692e+05
# max      4.560000e+07     1.600000e+07     1.014531e+07

# %%
#dropna, fillna

# %%
df2=df.fillna(0)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15000 non-null  int64
#  1   address          15000 non-null  object
#  2   city             15000 non-null  object
#  3   state            15000 non-null  object
#  4   zipcode          15000 non-null  int64
#  5   latitude         15000 non-null  float64
#  6   longitude        15000 non-null  float64
#  7   bedrooms         15000 non-null  int64
#  8   bathrooms        15000 non-null  float64
#  9   rooms            15000 non-null  int64
#  10  squareFootage    15000 non-null  int64
#  11  lotSize          15000 non-null  int64
#  12  yearBuilt        15000 non-null  float64
#  13  lastSaleDate     15000 non-null  object
#  14  lastSaleAmount   15000 non-null  int64
#  15  priorSaleDate    15000 non-null  object
#  16  priorSaleAmount  15000 non-null  float64
#  17  estimated_value  15000 non-null  int64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 2.1+ MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11078 entries, 0 to 14999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               11078 non-null  int64
#  1   address          11078 non-null  object
#  2   city             11078 non-null  object
#  3   state            11078 non-null  object
#  4   zipcode          11078 non-null  int64
#  5   latitude         11078 non-null  float64
#  6   longitude        11078 non-null  float64
#  7   bedrooms         11078 non-null  int64
#  8   bathrooms        11078 non-null  float64
#  9   rooms            11078 non-null  int64
#  10  squareFootage    11078 non-null  int64
#  11  lotSize          11078 non-null  int64
#  12  yearBuilt        11078 non-null  float64
#  13  lastSaleDate     11078 non-null  object
#  14  lastSaleAmount   11078 non-null  int64
#  15  priorSaleDate    11078 non-null  object
#  16  priorSaleAmount  11078 non-null  float64
#  17  estimated_value  11078 non-null  int64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 1.6+ MB

# %%
df.estimated_value
# Out:
# 0         239753
# 3         494073
# 4         513676
# 5         496062
# 6         514953
#           ...
# 14994     784955
# 14996     807306
# 14997    1737156
# 14998    2008794
# 14999    1421401
# Name: estimated_value, Length: 11078, dtype: int64

# %%
#box-plot, hist

# %%
sns.boxplot(df.estimated_value)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='estimated_value'>

# %%
df[['estimated_value','yearBuilt','priorSaleAmount']].head(2)
# Out:
#    estimated_value  yearBuilt  priorSaleAmount
# 0           239753     2003.0         165700.0
# 3           494073     1956.0              0.0

# %%
df = df[df.estimated_value<=1000000]

# %%
sns.boxplot(df.estimated_value)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='estimated_value'>

# %%
df.estimated_value.hist()
# Out:
# <AxesSubplot:>

# %%
 df[(df.estimated_value<=1000000)&(df.yearBuilt>2013)&(df.zipcode==80209)]
# Out:
#               id              address    city state  zipcode   latitude  \
# 13276   39512040        764 S York St  Denver    CO    80209  39.702607
# 13316   11586398        450 S Vine St  Denver    CO    80209  39.708351
# 13428   11586742    636 S Williams St  Denver    CO    80209  39.704969
# 13431  184305844        456 S High St  Denver    CO    80209  39.708197
# 13766    7652681    408 S Franklin St  Denver    CO    80209  39.709074
# 13812   39708952  611 S Washington St  Denver    CO    80209  39.705403
# 14162   30566405    876 S Williams St  Denver    CO    80209  39.700646
# 14982   43208991   731 S Elizabeth St  Denver    CO    80209  39.703135
#
#         longitude  bedrooms  bathrooms  rooms  squareFootage  lotSize  \
# 13276 -104.960243         3        4.0      7           2567     6250
# 13316 -104.962546         3        5.0      7           2570     4680
# 13428 -104.966025         3        5.0      6           2578     4680
# 13431 -104.964857         3        5.0     10           3346     6240
# 13766 -104.968369         3        5.0      8           3367     5060
# 13812 -104.979580         3        4.0     10           2090     4690
# 14162 -104.966016         3        1.0      8           3394     6250
# 14982 -104.956141         2        3.0      6           2680     6160
#
#        yearBuilt lastSaleDate  lastSaleAmount priorSaleDate  priorSaleAmount  \
# 13276     2016.0   2012-07-23          420000    2010-11-29         385000.0
# 13316     2016.0   2015-02-11          571000    2007-01-03         399000.0
# 13428     2016.0   2015-07-22          637600    2007-02-02         481900.0
# 13431     2016.0   2016-01-11          725000    1993-07-15         124000.0
# 13766     2015.0   2014-04-21          513486    2007-08-22         435000.0
# 13812     2014.0   2015-03-09          825000    2013-07-19         325500.0
# 14162     2015.0   2014-03-18          675000    2006-05-11         511000.0
# 14982     2016.0   2015-03-31          485000    2003-06-19         357500.0
#
#        estimated_value
# 13276           770622
# 13316           682810
# 13428           745777
# 13431           751361
# 13766           709102
# 13812           994114
# 14162           869769
# 14982           753935

# %%
df.zipcode.unique()
# Out:
# array([80022, 80033, 80123, 80203, 80204, 80205, 80206, 80207, 80209],
#       dtype=int64)

# %%
df = df[df.lastSaleAmount<=1000000]

# %%
#plot

# %%
sns.pairplot(df[['lastSaleAmount','estimated_value','zipcode']])

# %%
sns.stripplot(x=df.zipcode,y=df.estimated_value)
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='estimated_value'>

# %%
sns.violinplot(x=df.zipcode,y=df.estimated_value)
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='estimated_value'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10056 entries, 0 to 14996
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               10056 non-null  int64
#  1   address          10056 non-null  object
#  2   city             10056 non-null  object
#  3   state            10056 non-null  object
#  4   zipcode          10056 non-null  int64
#  5   latitude         10056 non-null  float64
#  6   longitude        10056 non-null  float64
#  7   bedrooms         10056 non-null  int64
#  8   bathrooms        10056 non-null  float64
#  9   rooms            10056 non-null  int64
#  10  squareFootage    10056 non-null  int64
#  11  lotSize          10056 non-null  int64
#  12  yearBuilt        10056 non-null  float64
#  13  lastSaleDate     10056 non-null  object
#  14  lastSaleAmount   10056 non-null  int64
#  15  priorSaleDate    10056 non-null  object
#  16  priorSaleAmount  10056 non-null  float64
#  17  estimated_value  10056 non-null  int64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 1.7+ MB

# %%
#date-time

# %%
df['priorSaleDate'] = pd.to_datetime(df.priorSaleDate)

# %%
df['lastSaleDate'] = pd.to_datetime(df.lastSaleDate)

# %%
df['weekday_lastSaleDate']=df.lastSaleDate.dt.weekday

# %%
df['year_lastSaleDate']=df.lastSaleDate.dt.year

# %%
df['year_priorSaleDate']=df.priorSaleDate.dt.year

# %%
df.head(1)
# Out:
#          id          address    city state  zipcode  latitude   longitude  \
# 0  39525749  8171 E 84th Ave  Denver    CO    80022  39.84916 -104.893468
#
#    bedrooms  bathrooms  rooms  ...  lotSize  yearBuilt  lastSaleDate  \
# 0         3        2.0      6  ...     9968     2003.0    2009-12-17
#
#   lastSaleAmount  priorSaleDate priorSaleAmount  estimated_value  \
# 0          75000     2004-05-13        165700.0           239753
#
#    weekday_lastSaleDate  year_lastSaleDate  year_priorSaleDate
# 0                     3               2009                2004
#
# [1 rows x 21 columns]

# %%
df['year_between_last_sales'] = df.year_lastSaleDate-df.year_priorSaleDate

# %%
df.head(1)
# Out:
#          id          address    city state  zipcode  latitude   longitude  \
# 0  39525749  8171 E 84th Ave  Denver    CO    80022  39.84916 -104.893468
#
#    bedrooms  bathrooms  rooms  ...  yearBuilt  lastSaleDate  lastSaleAmount  \
# 0         3        2.0      6  ...     2003.0    2009-12-17           75000
#
#   priorSaleDate  priorSaleAmount estimated_value  weekday_lastSaleDate  \
# 0    2004-05-13         165700.0          239753                     3
#
#    year_lastSaleDate  year_priorSaleDate  year_between_last_sales
# 0               2009                2004                        5
#
# [1 rows x 22 columns]

# %%
#corr - correlation

# %%
df.corr()
# Out:
#                                id   zipcode  latitude  longitude  bedrooms  \
# id                       1.000000 -0.011297 -0.048153   0.048387  0.039121
# zipcode                 -0.011297  1.000000  0.526403   0.391642 -0.046614
# latitude                -0.048153  0.526403  1.000000   0.549132 -0.018614
# longitude                0.048387  0.391642  0.549132   1.000000 -0.000402
# bedrooms                 0.039121 -0.046614 -0.018614  -0.000402  1.000000
# bathrooms                0.107386 -0.080346 -0.099648   0.097216  0.415339
# rooms                    0.054204 -0.003405 -0.126971  -0.010909  0.675945
# squareFootage            0.094452 -0.087891 -0.139466   0.027004  0.652693
# lotSize                 -0.019166 -0.075253  0.027390   0.106275 -0.016413
# yearBuilt               -0.006153 -0.226559 -0.009419   0.070333 -0.129642
# lastSaleAmount           0.235009  0.065523 -0.197746   0.196856  0.224836
# priorSaleAmount          0.013557  0.010375 -0.208449   0.153441  0.138312
# estimated_value          0.151873  0.109777 -0.199264   0.234486  0.358081
# weekday_lastSaleDate    -0.001664 -0.003422 -0.012104  -0.006020  0.005502
# year_lastSaleDate        0.215965  0.028791  0.048474   0.039119 -0.013530
# year_priorSaleDate      -0.041292  0.032874  0.119064   0.042747 -0.022331
# year_between_last_sales  0.196563 -0.012251 -0.084467  -0.014722  0.012653
#
#                          bathrooms     rooms  squareFootage   lotSize  \
# id                        0.107386  0.054204       0.094452 -0.019166
# zipcode                  -0.080346 -0.003405      -0.087891 -0.075253
# latitude                 -0.099648 -0.126971      -0.139466  0.027390
# longitude                 0.097216 -0.010909       0.027004  0.106275
# bedrooms                  0.415339  0.675945       0.652693 -0.016413
# bathrooms                 1.000000  0.549778       0.663715 -0.015200
# rooms                     0.549778  1.000000       0.733533 -0.118596
# squareFootage             0.663715  0.733533       1.000000 -0.047501
# lotSize                  -0.015200 -0.118596      -0.047501  1.000000
# yearBuilt                -0.013998 -0.251359      -0.190924  0.460479
# lastSaleAmount            0.506835  0.396264       0.501981 -0.068455
# priorSaleAmount           0.343256  0.284077       0.333408 -0.049009
# estimated_value           0.651712  0.582055       0.690419 -0.074329
# weekday_lastSaleDate     -0.002129  0.020427       0.003686  0.008917
# year_lastSaleDate         0.068560 -0.036699      -0.008145 -0.006770
# year_priorSaleDate        0.055031 -0.080663      -0.081598  0.030610
# year_between_last_sales  -0.005874  0.054452       0.075907 -0.035535
#
#                          yearBuilt  lastSaleAmount  priorSaleAmount  \
# id                       -0.006153        0.235009         0.013557
# zipcode                  -0.226559        0.065523         0.010375
# latitude                 -0.009419       -0.197746        -0.208449
# longitude                 0.070333        0.196856         0.153441
# bedrooms                 -0.129642        0.224836         0.138312
# bathrooms                -0.013998        0.506835         0.343256
# rooms                    -0.251359        0.396264         0.284077
# squareFootage            -0.190924        0.501981         0.333408
# lotSize                   0.460479       -0.068455        -0.049009
# yearBuilt                 1.000000       -0.172716        -0.116049
# lastSaleAmount           -0.172716        1.000000         0.626557
# priorSaleAmount          -0.116049        0.626557         1.000000
# estimated_value          -0.257927        0.771199         0.570242
# weekday_lastSaleDate     -0.004976       -0.001550        -0.000392
# year_lastSaleDate         0.028297        0.447020         0.170766
# year_priorSaleDate        0.065311        0.101286         0.176550
# year_between_last_sales  -0.045106        0.219734        -0.054190
#
#                          estimated_value  weekday_lastSaleDate  \
# id                              0.151873             -0.001664
# zipcode                         0.109777             -0.003422
# latitude                       -0.199264             -0.012104
# longitude                       0.234486             -0.006020
# bedrooms                        0.358081              0.005502
# bathrooms                       0.651712             -0.002129
# rooms                           0.582055              0.020427
# squareFootage                   0.690419              0.003686
# lotSize                        -0.074329              0.008917
# yearBuilt                      -0.257927             -0.004976
# lastSaleAmount                  0.771199             -0.001550
# priorSaleAmount                 0.570242             -0.000392
# estimated_value                 1.000000              0.001672
# weekday_lastSaleDate            0.001672              1.000000
# year_lastSaleDate               0.040228             -0.032359
# year_priorSaleDate             -0.059596             -0.017315
# year_between_last_sales         0.088621             -0.005904
#
#                          year_lastSaleDate  year_priorSaleDate  \
# id                                0.215965           -0.041292
# zipcode                           0.028791            0.032874
# latitude                          0.048474            0.119064
# longitude                         0.039119            0.042747
# bedrooms                         -0.013530           -0.022331
# bathrooms                         0.068560            0.055031
# rooms                            -0.036699           -0.080663
# squareFootage                    -0.008145           -0.081598
# lotSize                          -0.006770            0.030610
# yearBuilt                         0.028297            0.065311
# lastSaleAmount                    0.447020            0.101286
# priorSaleAmount                   0.170766            0.176550
# estimated_value                   0.040228           -0.059596
# weekday_lastSaleDate             -0.032359           -0.017315
# year_lastSaleDate                 1.000000            0.361335
# year_priorSaleDate                0.361335            1.000000
# year_between_last_sales           0.356532           -0.742332
#
#                          year_between_last_sales
# id                                      0.196563
# zipcode                                -0.012251
# latitude                               -0.084467
# longitude                              -0.014722
# bedrooms                                0.012653
# bathrooms                              -0.005874
# rooms                                   0.054452
# squareFootage                           0.075907
# lotSize                                -0.035535
# yearBuilt                              -0.045106
# lastSaleAmount                          0.219734
# priorSaleAmount                        -0.054190
# estimated_value                         0.088621
# weekday_lastSaleDate                   -0.005904
# year_lastSaleDate                       0.356532
# year_priorSaleDate                     -0.742332
# year_between_last_sales                 1.000000

# %%
type(df.corr())
# Out:
# pandas.core.frame.DataFrame

# %%
df.corr().loc['estimated_value',:]
# Out:
# id                         0.151873
# zipcode                    0.109777
# latitude                  -0.199264
# longitude                  0.234486
# bedrooms                   0.358081
# bathrooms                  0.651712
# rooms                      0.582055
# squareFootage              0.690419
# lotSize                   -0.074329
# yearBuilt                 -0.257927
# lastSaleAmount             0.771199
# priorSaleAmount            0.570242
# estimated_value            1.000000
# weekday_lastSaleDate       0.001672
# year_lastSaleDate          0.040228
# year_priorSaleDate        -0.059596
# year_between_last_sales    0.088621
# Name: estimated_value, dtype: float64

# %%
#groupby

# %%
df.groupby('zipcode').estimated_value.mean()
# Out:
# zipcode
# 80022    239753.000000
# 80033    494073.000000
# 80123    442041.557377
# 80203    596960.430830
# 80204    381987.303743
# 80205    493791.761835
# 80206    687289.934902
# 80207    501447.870112
# 80209    675992.140553
# Name: estimated_value, dtype: float64

# %%
df.groupby('zipcode').estimated_value.max()
# Out:
# zipcode
# 80022    239753
# 80033    494073
# 80123    784587
# 80203    987935
# 80204    885679
# 80205    989742
# 80206    996397
# 80207    992709
# 80209    996677
# Name: estimated_value, dtype: int64

# %%
df.groupby('zipcode').estimated_value.min()
# Out:
# zipcode
# 80022    239753
# 80033    494073
# 80123    299492
# 80203    273748
# 80204    147767
# 80205    215531
# 80206    327685
# 80207    265666
# 80209    299293
# Name: estimated_value, dtype: int64

# %%
df.groupby(['zipcode','yearBuilt']).estimated_value.median()
# Out:
# zipcode  yearBuilt
# 80022    2003.0       239753.0
# 80033    1956.0       494073.0
# 80123    1959.0       378509.0
#          1960.0       370857.0
#          1961.0       348035.0
#                         ...
# 80209    2008.0       749428.5
#          2010.0       686395.0
#          2014.0       994114.0
#          2015.0       789435.5
#          2016.0       751361.0
# Name: estimated_value, Length: 550, dtype: float64

# %%
type(df.groupby('zipcode').estimated_value.mean())
# Out:
# pandas.core.series.Series

# %%
df2 = df.groupby('zipcode').estimated_value.median().reset_index()

# %%
df2
# Out:
#    zipcode  estimated_value
# 0    80022         239753.0
# 1    80033         494073.0
# 2    80123         427234.5
# 3    80203         560032.0
# 4    80204         352036.5
# 5    80205         465961.0
# 6    80206         685462.0
# 7    80207         451622.0
# 8    80209         674813.0

# %%
df.head(2)
# Out:
#           id              address    city state  zipcode  latitude  \
# 0   39525749      8171 E 84th Ave  Denver    CO    80022  39.84916
# 3  155129946  3040 Wadsworth Blvd  Denver    CO    80033  39.76078
#
#     longitude  bedrooms  bathrooms  rooms  ...  yearBuilt  lastSaleDate  \
# 0 -104.893468         3        2.0      6  ...     2003.0    2009-12-17
# 3 -105.081060         4        3.0      0  ...     1956.0    2008-12-02
#
#    lastSaleAmount priorSaleDate  priorSaleAmount estimated_value  \
# 0           75000    2004-05-13         165700.0          239753
# 3          185000    2008-06-27              0.0          494073
#
#    weekday_lastSaleDate  year_lastSaleDate  year_priorSaleDate  \
# 0                     3               2009                2004
# 3                     1               2008                2008
#
#    year_between_last_sales
# 0                        5
# 3                        0
#
# [2 rows x 22 columns]

# %%
#merge

# %%
df3=pd.merge(df,df2, on='zipcode',how='left')

# %%
df3.head(2)
# Out:
#           id              address    city state  zipcode  latitude  \
# 0   39525749      8171 E 84th Ave  Denver    CO    80022  39.84916
# 1  155129946  3040 Wadsworth Blvd  Denver    CO    80033  39.76078
#
#     longitude  bedrooms  bathrooms  rooms  ...  lastSaleDate  lastSaleAmount  \
# 0 -104.893468         3        2.0      6  ...    2009-12-17           75000
# 1 -105.081060         4        3.0      0  ...    2008-12-02          185000
#
#    priorSaleDate priorSaleAmount  estimated_value_x weekday_lastSaleDate  \
# 0     2004-05-13        165700.0             239753                    3
# 1     2008-06-27             0.0             494073                    1
#
#    year_lastSaleDate  year_priorSaleDate  year_between_last_sales  \
# 0               2009                2004                        5
# 1               2008                2008                        0
#
#    estimated_value_y
# 0           239753.0
# 1           494073.0
#
# [2 rows x 23 columns]

# %%
df2.columns=['zipcode','median_value']

# %%
df2
# Out:
#    zipcode  median_value
# 0    80022      239753.0
# 1    80033      494073.0
# 2    80123      427234.5
# 3    80203      560032.0
# 4    80204      352036.5
# 5    80205      465961.0
# 6    80206      685462.0
# 7    80207      451622.0
# 8    80209      674813.0

# %%
df3=pd.merge(df,df2, on='zipcode',how='left')

# %%
df3.head(2)
# Out:
#           id              address    city state  zipcode  latitude  \
# 0   39525749      8171 E 84th Ave  Denver    CO    80022  39.84916
# 1  155129946  3040 Wadsworth Blvd  Denver    CO    80033  39.76078
#
#     longitude  bedrooms  bathrooms  rooms  ...  lastSaleDate  lastSaleAmount  \
# 0 -104.893468         3        2.0      6  ...    2009-12-17           75000
# 1 -105.081060         4        3.0      0  ...    2008-12-02          185000
#
#    priorSaleDate priorSaleAmount  estimated_value weekday_lastSaleDate  \
# 0     2004-05-13        165700.0           239753                    3
# 1     2008-06-27             0.0           494073                    1
#
#    year_lastSaleDate  year_priorSaleDate  year_between_last_sales  \
# 0               2009                2004                        5
# 1               2008                2008                        0
#
#    median_value
# 0      239753.0
# 1      494073.0
#
# [2 rows x 23 columns]

# %%
#DATA SET EXAMPLES
#KAGGLE: https://www.kaggle.com
#REDDIT:
#SKLEARN:http://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
#GOOGLE!
